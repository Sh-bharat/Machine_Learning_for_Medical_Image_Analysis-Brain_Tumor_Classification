# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Importing Libraries
import shutil
import cv2
import matplotlib.pyplot as plt

# %%
shutil.copytree('/content/drive/MyDrive/Brain_Tumor/runs','/content/runs')
# Out:
# '/content/runs'

# %% [markdown]
# # **Results**

# %%
plt.imshow(cv2.imread('/content/runs/classify/train/results.png')[:,:,::-1])

# %%
plt.imshow(cv2.imread('/content/runs/classify/train/confusion_matrix_normalized.png')[:,:,::-1])

# %% [markdown]
# # **OUTPUT**
# Prediction_batch_1

# %%
plt.imshow(cv2.imread('/content/runs/classify/train/val_batch0_labels.jpg')[:,:,::-1])

# %%
plt.imshow(cv2.imread('/content/runs/classify/train/val_batch0_pred.jpg')[:,:,::-1])

# %% [markdown]
# Prediction_batch_2

# %%
plt.imshow(cv2.imread('/content/runs/classify/train/val_batch1_labels.jpg')[:,:,::-1])

# %%
plt.imshow(cv2.imread('/content/runs/classify/train/val_batch1_pred.jpg')[:,:,::-1])
